# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\cash\\OneDrive\\Documentos\\ME!\\HR_dataset.txt')

# %%
df.head()
# Out:
#    0 Employee_ID        Full_Name  Department              Job_Title  \
# 0  0  EMP0000001    Joshua Nguyen          IT      Software Engineer
# 1  1  EMP0000002   Julie Williams   Marketing         SEO Specialist
# 2  2  EMP0000003  Alyssa Martinez          HR             HR Manager
# 3  3  EMP0000004  Nicholas Valdez          IT      Software Engineer
# 4  4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator
#
#     Hire_Date                                 Location  Performance_Rating  \
# 0  2011-08-10                       Isaacland, Denmark                   5
# 1  2018-03-02                  Anthonyside, Costa Rica                   2
# 2  2023-03-20         Port Christinaport, Saudi Arabia                   1
# 3  2023-10-12  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024-12-09     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode   Salary
# 0                14  Resigned   On-site  1585363
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2009 entries, 0 to 2008
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   0                   2009 non-null   int64
#  1   Employee_ID         2009 non-null   object
#  2   Full_Name           2009 non-null   object
#  3   Department          2009 non-null   object
#  4   Job_Title           2009 non-null   object
#  5   Hire_Date           2009 non-null   object
#  6   Location            2009 non-null   object
#  7   Performance_Rating  2009 non-null   int64
#  8   Experience_Years    2009 non-null   int64
#  9   Status              2009 non-null   object
#  10  Work_Mode           2009 non-null   object
#  11  Salary              2009 non-null   int64
# dtypes: int64(4), object(8)
# memory usage: 188.5+ KB

# %%
df.shape
# Out:
# (2009, 12)

# %%
df.drop(columns=['0'], axis=1, inplace=True)
df['Hire_Date'] = pd.to_datetime(df['Hire_Date'])
df['Monthly_Salary'] = round(df['Salary'] / 12, 2)

# %%
df.head()
# Out:
#   Employee_ID        Full_Name  Department              Job_Title  Hire_Date  \
# 0  EMP0000001    Joshua Nguyen          IT      Software Engineer 2011-08-10
# 1  EMP0000002   Julie Williams   Marketing         SEO Specialist 2018-03-02
# 2  EMP0000003  Alyssa Martinez          HR             HR Manager 2023-03-20
# 3  EMP0000004  Nicholas Valdez          IT      Software Engineer 2023-10-12
# 4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator 2024-12-09
#
#                                   Location  Performance_Rating  \
# 0                       Isaacland, Denmark                   5
# 1                  Anthonyside, Costa Rica                   2
# 2         Port Christinaport, Saudi Arabia                   1
# 3  Port Shelbychester, Antigua and Barbuda                   1
# 4     Lake Kimberly, Palestinian Territory                   5
#
#    Experience_Years    Status Work_Mode   Salary  Monthly_Salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2009 entries, 0 to 2008
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         2009 non-null   object
#  1   Full_Name           2009 non-null   object
#  2   Department          2009 non-null   object
#  3   Job_Title           2009 non-null   object
#  4   Hire_Date           2009 non-null   datetime64[ns]
#  5   Location            2009 non-null   object
#  6   Performance_Rating  2009 non-null   int64
#  7   Experience_Years    2009 non-null   int64
#  8   Status              2009 non-null   object
#  9   Work_Mode           2009 non-null   object
#  10  Salary              2009 non-null   int64
#  11  Monthly_Salary      2009 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 188.5+ KB

# %%
df.isnull().sum()
# Out:
# Employee_ID           0
# Full_Name             0
# Department            0
# Job_Title             0
# Hire_Date             0
# Location              0
# Performance_Rating    0
# Experience_Years      0
# Status                0
# Work_Mode             0
# Salary                0
# Monthly_Salary        0
# dtype: int64

# %%
df['Monthly_Salary'].describe()
# Out:
# count      2009.000000
# mean      74922.885879
# std       33383.928143
# min       25163.080000
# 25%       51221.000000
# 50%       68464.830000
# 75%       89779.920000
# max      249529.920000
# Name: Monthly_Salary, dtype: float64

# %%
sns.histplot(df['Monthly_Salary'], kde=True)
# Out:
# <Axes: xlabel='Monthly_Salary', ylabel='Count'>

# %%
plt.boxplot(df['Experience_Years'])
plt.title('Boxplot of Experience Years')
plt.ylabel('Experience Years')
plt.show()

# %%
plt.scatter(df['Experience_Years'], df['Monthly_Salary'])
plt.title('Experience Years vs Monthly Salary')
plt.xlabel('Experience Years')
plt.ylabel('Monthly Salary')
plt.show()

# %%
#df[df['Department'] == 'IT'].sort_values(by='Full_Name', ascending=True) 
df[(df['Work_Mode'] == 'On-site') & (df['Department'] == 'IT')].sort_values(by='Monthly_Salary', ascending=True)
# Out:
#      Employee_ID          Full_Name Department        Job_Title  Hire_Date  \
# 1411  EMP0001412        Krista Cook         IT     Data Analyst 2021-04-14
# 183   EMP0000184       Teresa Mills         IT              CTO 2024-03-24
# 782   EMP0000783     Kaylee Barnett         IT  DevOps Engineer 2022-01-02
# 1285  EMP0001286    Tiffany Walters         IT              CTO 2016-06-05
# 581   EMP0000582    Mr. Ryan Rivera         IT              CTO 2011-10-12
# ...          ...                ...        ...              ...        ...
# 34    EMP0000035   Kathleen Shields         IT       IT Manager 2023-07-26
# 885   EMP0000886      Rebecca Burch         IT       IT Manager 2025-04-25
# 1922  EMP0001923       Ivan Carlson         IT       IT Manager 2025-07-24
# 442   EMP0000443      Heidi Collins         IT       IT Manager 2016-05-31
# 1848  EMP0001849  Virginia Mitchell         IT       IT Manager 2024-10-23
#
# ...
